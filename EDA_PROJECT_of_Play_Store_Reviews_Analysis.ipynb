# %% [markdown]
# <a href="https://colab.research.google.com/github/vijendra56/Capstone-project/blob/main/EDA_PROJECT_of_Play_Store_Reviews_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #***Project Name***    -   Play Store App Review Analysis

# %% [markdown]
# ##### ***Project Type***    - EDA
# ##### ***Contribution***    - Individual

# %% [markdown]
# # ***Project Summary -***

# %% [markdown]
# Google Play Store  was launched on march 6,2012.Google play store is official pre-installed app on Android devices which provide access to the Google plat Store.It allows users to browse and download music,books,magazines,movies,television programs and applications from google play.There are more than 5 million apps found on Google Play Store. Lots of designers and developers work on it to make an app successful on the Play Store.
#
# The Google Play Store Review Analysis EDA (Exploratory Data Analysis) project is a data analysis project the aims to gain insights and understand patterns from the reviews of apps on the Google Play Store.The project involves conducting exploratory data analysis techniques to analyze a dataset of reviews,extract meaningful information and visualize the findings.
#
# The main objectives of the project may include:
#
#
# *   **Data Collection**:-Gathering a dataset of reviews from the Google Play Store,which may involve web scraping or accessing a pre-existing  dataset.
#
# *   **Data Cleaning & Preprocessing**:-Cleaning and preprocessing the collected data to remove irrelevant or duplicate information,handle missing values, and convert data into a suitable format for analysis.
#
#
# *   **Exploratory Data Analsis(EDA)**:-Conducting various EDA techniques,such as descriptive statistics,data visualization and data aggregation to gain insights and understand patterns in the data.This may involve analyzing key metrics, such as ratings,review text,app categories and user demographics to identify trends,patterns and correlations.
#
#
# *   **Sentiment Analysis**:- Performing sentiment analysis on the review text to categorize the reviews as positive,negative, or neutral. This may involve using natural language processing(NLP) techniques,such as text classification or using pre-trained sentiment analysis models.Sentiment analysis can provide insights on the overall user satisfaction and feedback regarding the apps.
#
# *   **Feature Engineering**:-Feature engineering involves creating new features or deriving meaningful insights from existing features in the data.For example,extracting features like review length ,review sentiment and app rating distribution can provide addtitional insights into the reviews data.
#
# *   **Insights and Recommendations**:-Based on the findings from the data analysis,insights and recommendations can be derived to provide actionable recommendations to app developers or businesses. For example,identifying popular features among users,or understanding user preferences can help app developers make informed decisions to improve their app and user experience.
#
#
# *   **Visualization and Reporting**:- Creating visualizations,such as bar charts,pie charts, and word clouds,to visually represent the findings from the EDA and sentiment analysis. Generating a summary report to present the key findings,insights and recommendations.

# %% [markdown]
# #***Problem Statement***

# %% [markdown]
# *   Best suitable android version for new app.
# *   Top category apps available in the play store.
# *   Analysis the sentiment subject and overall people's sentiment.
# *   Paid and free app ratio.
# *   Category wise free and paid apps.
# *   Age wise preferred category.
# *   Most reviewed apps.
# *   Look the sentiment column according to rating.
# *   Factors affecting installs.
# *   Top content rating per installations.
# *   Co-relation between installs,ratings and size.

# %% [markdown]
# # ***GitHub Link -***

# %% [markdown]
# https://github.com/vijendra56/Capstone-project/tree/main

# %% [markdown]
# #### ***Business Objective***

# %% [markdown]
# The business objective of the Play Store review analysis EDA project is to gain a deeper understanding of customer feedback and preferences,which can inform decisions about product development,marketing and customer support.Specifically,the project aims to:
#
#
# *   Identify common issues or complaints that customers have with the app and address them to improve customer satisfaction.
#
# *   Understand customers preferences and opinions about the app's features,design,and overall user experience to inform future product development.
#
#
# *   Track changes in customer sentiment and overall app rating over time to monitor the app's performance and identify areas for improvement.
#
# *   Use insights from the EDA to inform marketing strategies and messaging to better target and engage potential customers.
#
#
# *   Provide customer support teams with insights into common issues and complaints to improve the quality and speed of support.
# By achieving these objectives, the project can help the business improve customer satisfaction, increase app usage and retention, and ultimately drive revenue growth.

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# # ***Import Libraries***

# %%
import pandas as pd             # For data manipulation 
import numpy as np              # For mathematical operations and linear algebra
import seaborn as sns           # For data visualization
import matplotlib.pyplot as plt # For data visualization         
# %matplotlib inline

# %% [markdown]
# # ***Dataset Loading***

# %%
#mounting the drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
play_store = pd.read_csv('/content/drive/MyDrive/Play Store Data.csv')
user_reviews = pd.read_csv('/content/drive/MyDrive/User Reviews (1).csv')

# %% [markdown]
# ##***First 5 rows of dataset***

# %%
# For Play Store Dataset
play_store.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
# For User Reviews Dataset
user_reviews.head()
# Out:
#                      App                                  Translated_Review  \
# 0  10 Best Foods for You  I like eat delicious food. That's I'm cooking ...
# 1  10 Best Foods for You    This help eating healthy exercise regular basis
# 2  10 Best Foods for You                                                NaN
# 3  10 Best Foods for You         Works great especially going grocery store
# 4  10 Best Foods for You                                       Best idea us
#
#   Sentiment  Sentiment_Polarity  Sentiment_Subjectivity
# 0  Positive                1.00                0.533333
# 1  Positive                0.25                0.288462
# 2       NaN                 NaN                     NaN
# 3  Positive                0.40                0.875000
# 4  Positive                1.00                0.300000

# %% [markdown]
# ##***Columns of Dataset***

# %%
# For Play Store Dataset
play_store.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
# For User Reviews Dataset
user_reviews.columns
# Out:
# Index(['App', 'Translated_Review', 'Sentiment', 'Sentiment_Polarity',
#        'Sentiment_Subjectivity'],
#       dtype='object')

# %% [markdown]
# # ***Variables Description***

# %% [markdown]
# ##***Variables are used in this dataset***
#
# ##***Playstore variables***##
#
# ###**There are 13 columns in this data :**###
#
# 1.**App -** It tells us about the name of the application.
#
# 2.**Category -** It tells us about the category to which an application belongs.
#
# 3.**Rating -** It tells us about the ratings given by the users for a specific application.
#
# 4.**Reviews -** It tells us about the total number of users who have given a review for the application.
#
# 5.**Size -**  It tells us about the size being occupied the application on the mobile phone.
#
# 6.**Installs -**  It tells us about the total number of installs/downloads for an application.
#
# 7.**Type -** It tells us whether the application is free or a paid one.
#
# 8.**Price -** It tells us about the price of the application.
#
# 9.**Content_Rating -** It tells us about the target audience for the application.
#
# 10.**Genres -** It tells us about the various other categories to which an application can belong.
#
# 11.**Last_Updated -** It tells us about the when the application was updated.
#
# 12.**Current_Ver -** It tells us about the current version of the application.
#
# 13.**Android_Ver -** It tells us about the android version which can support the application on its platform.

# %% [markdown]
# ##***User reviews variables***##
# ###**There are 5 columns in this dataset** :###
#
# 1. **App -** It contains the name or identifier of the app
#
# 2.  **Translated_Review -** It contains the text of the review
#
# 3.  **Sentiment -** It contains the overall sentiment of the review (e.g. positive or negative)
# 4.  **Sentiment_Polarity -** Itcontains a measure of the positivity or negativity of the review
# 5.**Sentiment_Subjectivity -** It contains a measure of the subjectivity or objectivity of the review. These columns could be useful for analyzing the sentiment of app reviews and understanding how users feel about different apps.

# %% [markdown]
# ##***Number of rows and columns***

# %%
# For Play Store Dataset
play_store.shape
print(f"The shape of PlayStore dataframe is {play_store.shape}")
# Out:
# The shape of PlayStore dataframe is (10841, 13)

# %%
# For User Reviews Dataset
user_reviews.shape
print(f"The shape of User Reviews dataframe is {user_reviews.shape}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-22016a5643b6> in <cell line: 2>()
#       1 # For User Reviews Dataset
# ----> 2 user_reviews.shape
#       3 print(f"The shape of User Reviews dataframe is {user_reviews.shape}")
#
# NameError: name 'user_reviews' is not defined

# %% [markdown]
# ##***Dataset Information***

# %%
# For Play Store Dataset
play_store.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
# For User Reviews Dataset
user_reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64295 entries, 0 to 64294
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   App                     64295 non-null  object
#  1   Translated_Review       37427 non-null  object
#  2   Sentiment               37432 non-null  object
#  3   Sentiment_Polarity      37432 non-null  float64
#  4   Sentiment_Subjectivity  37432 non-null  float64
# dtypes: float64(2), object(3)
# memory usage: 2.5+ MB

# %% [markdown]
# ##***Descriptive Statistics***

# %%
# For Play Store Dataset
play_store.describe()
# Out:
#             Rating
# count  9367.000000
# mean      4.193338
# std       0.537431
# min       1.000000
# 25%       4.000000
# 50%       4.300000
# 75%       4.500000
# max      19.000000

# %%
# For User Reviews Dataset
user_reviews.describe()
# Out:
#        Sentiment_Polarity  Sentiment_Subjectivity
# count        37432.000000            37432.000000
# mean             0.182146                0.492704
# std              0.351301                0.259949
# min             -1.000000                0.000000
# 25%              0.000000                0.357143
# 50%              0.150000                0.514286
# 75%              0.400000                0.650000
# max              1.000000                1.000000

# %% [markdown]
# #***Data Wrangling***

# %% [markdown]
# ##***Missing Values in the dataset***

# %%
# For Play Store Dataset
play_store.isnull().sum().sort_values(ascending = False)
# Out:
# Rating            1474
# Current Ver          8
# Android Ver          3
# Type                 1
# Content Rating       1
# App                  0
# Category             0
# Reviews              0
# Size                 0
# Installs             0
# Price                0
# Genres               0
# Last Updated         0
# dtype: int64

# %%
import matplotlib   
plt.figure(figsize = (20,6))
sns.heatmap(play_store.isnull(),yticklabels = False,cbar = False,cmap ='viridis')
plt.title('Missing null values')
# Out:
# Text(0.5, 1.0, 'Missing null values')

# %%
# For User Review Dataset
user_reviews.isnull().sum().sort_values(ascending = False)
# Out:
# Translated_Review         26868
# Sentiment                 26863
# Sentiment_Polarity        26863
# Sentiment_Subjectivity    26863
# App                           0
# dtype: int64

# %%
import matplotlib
plt.figure(figsize = (20,6))
sns.heatmap(user_reviews.isnull(),yticklabels = False,cbar = False,cmap ='viridis')
plt.title('Missing null values')
# Out:
# Text(0.5, 1.0, 'Missing null values')

# %% [markdown]
# ##***Missing percentage in dataset***

# %%
# For Play Store Dataset
missing_percentage_ps = play_store.isnull().sum().sort_values(ascending = False)/len(play_store)
missing_percentage_ps
# Out:
# Rating            0.135965
# Current Ver       0.000738
# Android Ver       0.000277
# Type              0.000092
# Content Rating    0.000092
# App               0.000000
# Category          0.000000
# Reviews           0.000000
# Size              0.000000
# Installs          0.000000
# Price             0.000000
# Genres            0.000000
# Last Updated      0.000000
# dtype: float64

# %% [markdown]
# The number of null values are:
#
# 1.Rating has 1474 null values which contributes 13.60% of the data.
#
# 2.Type has 1 null value which contributes 0.01% of the data.
#
# 3.Content_Rating has 1 null value which contributes 0.01% of the data.
#
# 4.Current_Ver has 8 null values which contributes 0.07% of the data.
#
# 5.Android_Ver has 3 null values which contributes 0.03% of the data.

# %%
 # For User Reviews Dataset
missing_percentage_ur = user_reviews.isnull().sum().sort_values(ascending = False)/len(user_reviews)
missing_percentage_ur
# Out:
# Translated_Review         0.417886
# Sentiment                 0.417809
# Sentiment_Polarity        0.417809
# Sentiment_Subjectivity    0.417809
# App                       0.000000
# dtype: float64

# %% [markdown]
# The number of null values are:
#
# 1.Translated_Review has 26868 null values which contributes 41.79% of the data.
#
# 2.Sentiment has 26863 null values which contributes 41.78% of the data.
#
# 3.Sentiment_Polarity has 26863 null values which contributes 41.78% of the data.
#
# 4.Sentiment_Subjectivity has 26863 null values which contributes 41.78% of the data.

# %% [markdown]
# ##***Exploratory Analysis and Visualization***
# ###***Plot the missing null values***

# %% [markdown]
# ##***Missing percentage of null values***

# %%
missing_percentage_ps = missing_percentage_ps[missing_percentage_ps!=0]    # Only the missing data
import matplotlib
plt.figure(figsize = (20,6))
missing_percentage_ps.plot(kind = 'barh')
plt.title('Missing percentage play store of null values')
# Out:
# Text(0.5, 1.0, 'Missing percentage play store of null values')

# %%
missing_percentage_ur = missing_percentage_ur[missing_percentage_ur!=0]    # Only the missing data
import matplotlib
plt.figure(figsize = (20,6))
missing_percentage_ur.plot(kind = 'barh')
plt.title('Missing percentage user reviews of null values')
# Out:
# Text(0.5, 1.0, 'Missing percentage user reviews of null values')

# %% [markdown]
# ##***About Dataset***
# The PlayStore dataframe has a shape of **(10841, 13)**, which means it has '**10841**' rows and '**13**' columns. The UserReview dataframe has a shape of **(64295, 5)**, which means it has '**64295**' rows and '**5**' columns.
#
# There are several null values present in both dataframes. In the PlayStore dataframe, there are '1**474**' null values in the Rating column, '**1**' null value in the Type column, '**1**' null value in the Content Rating column, '**8**' null values in the Current Ver column, and '**3**' null values in the Android Ver column.
#
# In the UserReview dataframe, there are '**26868**' null values in the Translated_Review column, '**26863**' null values in the Sentiment column, '**26863**' null values in the Sentiment_Polarity column, and '**26863**' null values in the Sentiment_Subjectivity column.

# %% [markdown]
# ##***Droping the null values from the rows***

# %%
play_store.dropna(subset = ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
       'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
       'Android Ver'],inplace = True)

# %%
play_store.isnull().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              0
# Price             0
# Content Rating    0
# Genres            0
# Last Updated      0
# Current Ver       0
# Android Ver       0
# dtype: int64

# %%
user_reviews.dropna(subset = ['App', 'Translated_Review', 'Sentiment', 'Sentiment_Polarity',
       'Sentiment_Subjectivity'],inplace = True)

# %%
user_reviews.isnull().sum()
# Out:
# App                       0
# Translated_Review         0
# Sentiment                 0
# Sentiment_Polarity        0
# Sentiment_Subjectivity    0
# dtype: int64

# %% [markdown]
# ##***Cleaning the data***

# %%
play_store_boolean = play_store['App'].duplicated().any()
play_store_boolean
# Out:
# True

# %%
play_store['App'].value_counts()
# Out:
# ROBLOX                                               9
# CBS Sports App - Scores, News, Stats & Watch Live    8
# 8 Ball Pool                                          7
# Duolingo: Learn Languages Free                       7
# Candy Crush Saga                                     7
#                                                     ..
# Math Games for Pre-K - Grade 4                       1
# Radio K - KUOM                                       1
# Kpop Music Quiz (K-pop Game)                         1
# OST)                                                 1
# iHoroscope - 2018 Daily Horoscope & Astrology        1
# Name: App, Length: 8190, dtype: int64

# %% [markdown]
# **From the above cell output we can see that App column has multiple rows.Let's check out that data in those rows is identical or not**

# %%
play_store[play_store['App'] == 'ROBLOX']
# Out:
#          App Category  Rating  Reviews Size      Installs  Type Price  \
# 1653  ROBLOX     GAME     4.5  4447388  67M  100,000,000+  Free     0
# 1701  ROBLOX     GAME     4.5  4447346  67M  100,000,000+  Free     0
# 1748  ROBLOX     GAME     4.5  4448791  67M  100,000,000+  Free     0
# 1841  ROBLOX     GAME     4.5  4449882  67M  100,000,000+  Free     0
# 1870  ROBLOX     GAME     4.5  4449910  67M  100,000,000+  Free     0
# 2016  ROBLOX   FAMILY     4.5  4449910  67M  100,000,000+  Free     0
# 2088  ROBLOX   FAMILY     4.5  4450855  67M  100,000,000+  Free     0
# 2206  ROBLOX   FAMILY     4.5  4450890  67M  100,000,000+  Free     0
# 4527  ROBLOX   FAMILY     4.5  4443407  67M  100,000,000+  Free     0
#
#      Content Rating                        Genres   Last Updated  \
# 1653   Everyone 10+  Adventure;Action & Adventure  July 31, 2018
# 1701   Everyone 10+  Adventure;Action & Adventure  July 31, 2018
# 1748   Everyone 10+  Adventure;Action & Adventure  July 31, 2018
# ...

# %%
play_store['Reviews'].duplicated().any()
# Out:
# True

# %%
play_store.duplicated('Reviews').sum()
# Out:
# 3370

# %%
play_store.drop_duplicates(subset=['Reviews'])
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 5                             Paper flowers instructions       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10817                               HTC Sense Input - FR                TOOLS
# 10826          Frim: get new friends on local chat rooms               SOCIAL
# 10829                     Bulgarian French Dictionary Fr  BOOKS_AND_REFERENCE
# 10832                                           FR Tides              WEATHER
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
play_store['Reviews'].value_counts()
# Out:
# 2         83
# 3         78
# 5         74
# 4         74
# 1         67
#           ..
# 666521     1
# 342912     1
# 4272       1
# 5517       1
# 398307     1
# Name: Reviews, Length: 5990, dtype: int64

# %%
user_reviews_boolean = user_reviews['App'].duplicated().any()
user_reviews_boolean
# Out:
# True

# %%
user_reviews['App'].value_counts()
# Out:
# Bowmasters                        312
# Helix Jump                        273
# Angry Birds Classic               273
# Calorie Counter - MyFitnessPal    254
# Duolingo: Learn Languages Free    240
#                                  ...
# Draw a Stickman: EPIC 2             1
# HD Camera                           1
# Draw In                             1
# Draw A Stickman                     1
# Best Fiends - Free Puzzle Game      1
# Name: App, Length: 865, dtype: int64

# %%
user_reviews[user_reviews['App'] == 'Bowmasters']
# Out:
#               App                                  Translated_Review  \
# 16887  Bowmasters  Really like game far. Great gameplay lots fun....
# 16888  Bowmasters  Easy play round two minutes. Characters hilari...
# 16889  Bowmasters  I would give game stars many problems. Lag eve...
# 16890  Bowmasters  It's ok, making us pay per week ads absurd edi...
# 16891  Bowmasters  Should vary videos required watch, least give ...
# ...           ...                                                ...
# 17202  Bowmasters  It really good lots fun addictive I would say ...
# 17203  Bowmasters  Its pretty addicting please fix guy CD broken....
# 17204  Bowmasters  This magical game children play. If like wonde...
# 17205  Bowmasters  Little reason keep playing. Only way earn coin...
# 17206  Bowmasters  Its fun short round pvp ridiculously gruesome ...
#
#       Sentiment  Sentiment_Polarity  Sentiment_Subjectivity
# 16887  Positive            0.116667                0.542593
# ...

# %%
user_reviews['Translated_Review'].duplicated().any()
# Out:
# True

# %%
user_reviews['Translated_Review'].duplicated().sum()
# Out:
# 9433

# %%
user_reviews.drop_duplicates(subset=['Translated_Review'],inplace=True)

# %%
user_reviews['Translated_Review'].value_counts()
# Out:
# I like eat delicious food. That's I'm cooking food myself, case "10 Best Foods" helps lot, also "Best Before (Shelf Life)"                                                                                                                                                                                                                                                    1
# This saving life, I ADHD Fabulous like little friend reminding gently things I wanted get done. My mind positively rewired start repeat daily habits,yhis us I struggle. I feel hope fir future app. Amazing !                                                                                                                                                                1
# ...

# %% [markdown]
# ##***Explore the numerical columns***

# %%
play_store['Installs'].unique()
# Out:
# array(['10,000+', '500,000+', '5,000,000+', '50,000,000+', '100,000+',
#        '50,000+', '1,000,000+', '10,000,000+', '5,000+', '100,000,000+',
#        '1,000,000,000+', '1,000+', '500,000,000+', '100+', '500+', '10+',
#        '5+', '50+', '1+'], dtype=object)

# %%
play_store['Installs'] = play_store['Installs'].str.split('+').str[0]       # Removes the + symbol
play_store['Installs'].replace(',','',regex = True, inplace=True)           # Replace the commas ',' in the install column
play_store['Installs'] = play_store['Installs'].astype(int)                 # Converting it to the int type

# %%
play_store['Installs'].unique()
# Out:
# array([     10000,     500000,    5000000,   50000000,     100000,
#             50000,    1000000,   10000000,       5000,  100000000,
#        1000000000,       1000,  500000000,        100,        500,
#                10,          5,         50,          1])

# %%
play_store['Size'].unique()
# Out:
# array(['19M', '14M', '8.7M', '25M', '2.8M', '5.6M', '29M', '33M', '3.1M',
#        '28M', '12M', '20M', '21M', '37M', '5.5M', '17M', '39M', '31M',
#        '4.2M', '23M', '6.0M', '6.1M', '4.6M', '9.2M', '5.2M', '11M',
#        '24M', 'Varies with device', '9.4M', '15M', '10M', '1.2M', '26M',
#        '8.0M', '7.9M', '56M', '57M', '35M', '54M', '201k', '3.6M', '5.7M',
#        '8.6M', '2.4M', '27M', '2.7M', '2.5M', '7.0M', '16M', '3.4M',
#        '8.9M', '3.9M', '2.9M', '38M', '32M', '5.4M', '18M', '1.1M',
#        '2.2M', '4.5M', '9.8M', '52M', '9.0M', '6.7M', '30M', '2.6M',
#        '7.1M', '22M', '6.4M', '3.2M', '8.2M', '4.9M', '9.5M', '5.0M',
#        '5.9M', '13M', '73M', '6.8M', '3.5M', '4.0M', '2.3M', '2.1M',
#        '42M', '9.1M', '55M', '23k', '7.3M', '6.5M', '1.5M', '7.5M', '51M',
#        '41M', '48M', '8.5M', '46M', '8.3M', '4.3M', '4.7M', '3.3M', '40M',
#        '7.8M', '8.8M', '6.6M', '5.1M', '61M', '66M', '79k', '8.4M',
# ...

# %%
play_store['Size'] = play_store['Size'].apply(lambda x:str(x).replace('M','')if 'M' in str(x) else x)

# %%
play_store['Size'] = play_store['Size'].apply(lambda x:str(x).replace(',','.')if ',' in str(x) else x)

# %% [markdown]
# **Conversion Kbs to Mb**

# %%
play_store['Size'] = play_store['Size'].apply(lambda x:float(str(x).replace('k',''))/1000 if 'k' in str(x) else x)

# %%
play_store['Size'] = play_store['Size'].apply(lambda x:float(str(x).replace('Varies with device','0') if 'Varies with device' in str(x) else x))

# %%
play_store.dtypes['Size']
# Out:
# dtype('float64')

# %%
play_store['Content Rating']
# Out:
# 0          Everyone
# 1          Everyone
# 2          Everyone
# 3              Teen
# 4          Everyone
#             ...
# 10834      Everyone
# 10836      Everyone
# 10837      Everyone
# 10839    Mature 17+
# 10840      Everyone
# Name: Content Rating, Length: 9360, dtype: object

# %%
play_store['Type']
# Out:
# 0        Free
# 1        Free
# 2        Free
# 3        Free
# 4        Free
#          ...
# 10834    Free
# 10836    Free
# 10837    Free
# 10839    Free
# 10840    Free
# Name: Type, Length: 9360, dtype: object

# %%
play_store['Type'].unique()
# Out:
# array(['Free', 'Paid'], dtype=object)

# %%
play_store['Price']
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 10834    0
# 10836    0
# 10837    0
# 10839    0
# 10840    0
# Name: Price, Length: 9360, dtype: object

# %%
play_store['Price'].unique()
# Out:
# array(['0', '$4.99', '$3.99', '$6.99', '$7.99', '$5.99', '$2.99', '$3.49',
#        '$1.99', '$9.99', '$7.49', '$0.99', '$9.00', '$5.49', '$10.00',
#        '$24.99', '$11.99', '$79.99', '$16.99', '$14.99', '$29.99',
#        '$12.99', '$2.49', '$10.99', '$1.50', '$19.99', '$15.99', '$33.99',
#        '$39.99', '$3.95', '$4.49', '$1.70', '$8.99', '$1.49', '$3.88',
#        '$399.99', '$17.99', '$400.00', '$3.02', '$1.76', '$4.84', '$4.77',
#        '$1.61', '$2.50', '$1.59', '$6.49', '$1.29', '$299.99', '$379.99',
#        '$37.99', '$18.99', '$389.99', '$8.49', '$1.75', '$14.00', '$2.00',
#        '$3.08', '$2.59', '$19.40', '$3.90', '$4.59', '$15.46', '$3.04',
#        '$13.99', '$4.29', '$3.28', '$4.60', '$1.00', '$2.95', '$2.90',
#        '$1.97', '$2.56', '$1.20'], dtype=object)

# %%
play_store['Content Rating'].unique()
# Out:
# array(['Everyone', 'Teen', 'Everyone 10+', 'Mature 17+',
#        'Adults only 18+', 'Unrated'], dtype=object)

# %%
play_store['Content Rating'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0          Everyone
# 1          Everyone
# 2          Everyone
# 3              Teen
# 4          Everyone
#             ...
# 10834      Everyone
# 10836      Everyone
# 10837      Everyone
# 10839    Mature 17+
# 10840      Everyone
# Name: Content Rating, Length: 9360, dtype: object>

# %%
play_store['Content Rating'] = play_store['Content Rating'].replace('Unrated','Everyone')
play_store['Content Rating'] = play_store['Content Rating'].replace('Everyone 10+','Teen')
play_store['Content Rating'] = play_store['Content Rating'].replace('Mature 17+','Adults')
play_store['Content Rating'] = play_store['Content Rating'].replace('Adults only 18+','Adults')

# %%
play_store['Content Rating'].unique()
# Out:
# array(['Everyone', 'Teen', 'Adults'], dtype=object)

# %%
play_store.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9360 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             9360 non-null   object
#  1   Category        9360 non-null   object
#  2   Rating          9360 non-null   float64
#  3   Reviews         9360 non-null   object
#  4   Size            9360 non-null   float64
#  5   Installs        9360 non-null   int64
#  6   Type            9360 non-null   object
#  7   Price           9360 non-null   object
#  8   Content Rating  9360 non-null   object
#  9   Genres          9360 non-null   object
#  10  Last Updated    9360 non-null   object
#  11  Current Ver     9360 non-null   object
#  12  Android Ver     9360 non-null   object
# dtypes: float64(2), int64(1), object(10)
# memory usage: 1023.8+ KB

# %%
play_store.boxplot('Rating')
# Out:
# <Axes: >

# %% [markdown]
# we have ratings which exceed the normal rating system i.e more than 5 as shown in the box plot

# %%
play_store['Rating'].unique()
# Out:
# array([4.1, 3.9, 4.7, 4.5, 4.3, 4.4, 3.8, 4.2, 4.6, 4. , 4.8, 4.9, 3.6,
#        3.7, 3.2, 3.3, 3.4, 3.5, 3.1, 5. , 2.6, 3. , 1.9, 2.5, 2.8, 2.7,
#        1. , 2.9, 2.3, 2.2, 1.7, 2. , 1.8, 2.4, 1.6, 2.1, 1.4, 1.5, 1.2])

# %%
play_store['Android Ver'].unique()
# Out:
# array(['4.0.3 and up', '4.2 and up', '4.4 and up', '2.3 and up',
#        '3.0 and up', '4.1 and up', '4.0 and up', '2.3.3 and up',
#        'Varies with device', '2.2 and up', '5.0 and up', '6.0 and up',
#        '1.6 and up', '1.5 and up', '2.1 and up', '7.0 and up',
#        '4.3 and up', '4.0.3 - 7.1.1', '2.0 and up', '3.2 and up',
#        '4.4W and up', '5.1 and up', '7.1 and up', '7.0 - 7.1.1',
#        '8.0 and up', '5.0 - 8.0', '3.1 and up', '2.0.1 and up',
#        '4.1 - 7.1.1', '5.0 - 6.0', '1.0 and up'], dtype=object)

# %% [markdown]
# ##***Top Categories installed from the Google play store***

# %%
play_store['Category'].unique()
# Out:
# array(['ART_AND_DESIGN', 'AUTO_AND_VEHICLES', 'BEAUTY',
#        'BOOKS_AND_REFERENCE', 'BUSINESS', 'COMICS', 'COMMUNICATION',
#        'DATING', 'EDUCATION', 'ENTERTAINMENT', 'EVENTS', 'FINANCE',
#        'FOOD_AND_DRINK', 'HEALTH_AND_FITNESS', 'HOUSE_AND_HOME',
#        'LIBRARIES_AND_DEMO', 'LIFESTYLE', 'GAME', 'FAMILY', 'MEDICAL',
#        'SOCIAL', 'SHOPPING', 'PHOTOGRAPHY', 'SPORTS', 'TRAVEL_AND_LOCAL',
#        'TOOLS', 'PERSONALIZATION', 'PRODUCTIVITY', 'PARENTING', 'WEATHER',
#        'VIDEO_PLAYERS', 'NEWS_AND_MAGAZINES', 'MAPS_AND_NAVIGATION'],
#       dtype=object)

# %%
top_category = play_store.Category.value_counts().reset_index().rename(columns={'Category':'Reviews','index':'Category'})
top_category
# Out:
#                Category  Reviews
# 0                FAMILY     1746
# 1                  GAME     1097
# 2                 TOOLS      733
# 3          PRODUCTIVITY      351
# 4               MEDICAL      350
# 5         COMMUNICATION      328
# 6               FINANCE      323
# 7                SPORTS      319
# 8           PHOTOGRAPHY      317
# 9             LIFESTYLE      314
# 10      PERSONALIZATION      312
# 11             BUSINESS      303
# 12   HEALTH_AND_FITNESS      297
# 13               SOCIAL      259
# 14             SHOPPING      238
# 15   NEWS_AND_MAGAZINES      233
# 16     TRAVEL_AND_LOCAL      226
# 17               DATING      195
# 18  BOOKS_AND_REFERENCE      178
# 19        VIDEO_PLAYERS      160
# 20            EDUCATION      155
# 21        ENTERTAINMENT      149
# 22  MAPS_AND_NAVIGATION      124
# 23       FOOD_AND_DRINK      109
# 24       HOUSE_AND_HOME       76
# 25              WEATHER       75
# 26    AUTO_AND_VEHICLES       73
# ...

# %%
Category_installs = play_store.groupby(['Category'])[['Installs']].sum()
Category_installs
# Out:
#                         Installs
# Category
# ART_AND_DESIGN         124228100
# AUTO_AND_VEHICLES       53129800
# BEAUTY                  26916200
# BOOKS_AND_REFERENCE   1921291655
# BUSINESS              1001768120
# COMICS                  56036100
# COMMUNICATION        32647241530
# DATING                 264295110
# EDUCATION              871352000
# ENTERTAINMENT         2869160000
# EVENTS                  15949410
# FAMILY               10257651590
# FINANCE                876612400
# FOOD_AND_DRINK         273777750
# GAME                 35085862717
# HEALTH_AND_FITNESS    1583056220
# HOUSE_AND_HOME         168582000
# LIBRARIES_AND_DEMO      61083000
# LIFESTYLE              537561120
# MAPS_AND_NAVIGATION    724267560
# MEDICAL                 53205576
# NEWS_AND_MAGAZINES    7496210650
# PARENTING               31116110
# PERSONALIZATION       2325341930
# PHOTOGRAPHY          10088243130
# PRODUCTIVITY         14176070180
# SHOPPING              3247831540
# ...

# %%
top_category_installs = pd.merge(top_category,Category_installs,on='Category')
top_category_installs.head()
# Out:
#        Category  Reviews     Installs
# 0        FAMILY     1746  10257651590
# 1          GAME     1097  35085862717
# 2         TOOLS      733  11450224500
# 3  PRODUCTIVITY      351  14176070180
# 4       MEDICAL      350     53205576

# %%
plt.figure(figsize =(14,7))
plt.xticks(rotation=60)
plt.xlabel('Category')
plt.ylabel('Number of Applications')
plt.title('Total Category and reviews of applications in each category')
sns.barplot(x = top_category_installs.Category,y=top_category_installs.Reviews)
# Out:
# <Axes: title={'center': 'Total Category and reviews of applications in each category'}, xlabel='Category', ylabel='Reviews'>

# %%
plt.figure(figsize =(14,7))
plt.xticks(rotation=60)
plt.xlabel('Category')
plt.ylabel('Number of Applications')
plt.title('Total Categories and Installation of Applications in each category')
sns.barplot(x = top_category_installs.Category,y=top_category_installs.Installs)
# Out:
# <Axes: title={'center': 'Total Categories and Installation of Applications in each category'}, xlabel='Category', ylabel='Installs'>

# %%
plt.figure(figsize =(14,7))
g = sns.kdeplot(play_store.Rating,color='Blue',shade =True)
g.set_xlabel('Rating')
g.set_ylabel('Frequency')
plt.title('Distribution of Rating',size = 20)
# Out:
# <ipython-input-68-a835d3e8bad0>:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   g = sns.kdeplot(play_store.Rating,color='Blue',shade =True)
# Text(0.5, 1.0, 'Distribution of Rating')

# %%
plt.title('Rating')
sns.histplot(play_store.Rating,kde = True,bins=5)
# Out:
# <Axes: title={'center': 'Rating'}, xlabel='Rating', ylabel='Count'>

# %% [markdown]
# 1.  Most apps have the rating between 4 to 5.
# 2.  Also shows us most apps are liked by many users depending on ease of use, funtionality, performance and less bugs.
#
# Definitly a positive impact on bussiness.Because now they have the users trust they can experiment on scaling the app and with pricing. Increrase their functionality globally. Reduces adverisement cost. Mainly they can also divert this taffic to thier next projects which helps them becoming a brand.

# %%
plt.figure(figsize=(14,7))
plt.xticks(rotation=60)
plt.xlabel('Highest Rated Category')
plt.ylabel('Number of Applications')
plt.title('All Categories Rating')
sns.barplot(x = play_store.Category,y = play_store.Rating)
# Out:
# <Axes: title={'center': 'All Categories Rating'}, xlabel='Category', ylabel='Rating'>

# %% [markdown]
# 1.  Most categories have the rating between 4 to 5.
# 2.  Also shows us most categories are liked by many users depending on ease of use, funtionality, performance and less bugs.
#
# Definetly a positive impact on buisness.Because now they have the users trust they can experiment on scaling the app and with pricing. Increrase their functionality globally. Reduces adverisement cost. Mainly they can also divert this taffic to thier next projects which helps them becoming a brand.

# %%
plt.figure(figsize=(8,8))
plt.title('Content Rating and Maximum Installations')
sns.scatterplot(x='Installs',y='Rating',data = play_store,hue='Content Rating')
# Out:
# <Axes: title={'center': 'Content Rating and Maximum Installations'}, xlabel='Installs', ylabel='Rating'>

# %%
app_count = play_store.groupby(['Category','Type'])[['App']].count().reset_index().rename(columns={'App':'Reviews'})
play_store_app_count = app_count.pivot('Category','Type','Reviews').fillna(0).reset_index()
# Out:
# <ipython-input-72-d437155c7187>:2: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   play_store_app_count = app_count.pivot('Category','Type','Reviews').fillna(0).reset_index()

# %%
play_store_app_count.set_index('Category').plot(kind='bar',stacked=True,figsize=(14,7))
plt.xlabel('Category',fontsize=15)
plt.ylabel('Reviews',fontsize=15)
plt.title('Free and Paid Apps in Category')
# Out:
# Text(0.5, 1.0, 'Free and Paid Apps in Category')

# %%
play_store['Installs'].min(),play_store['Installs'].max()
# Out:
# (1, 1000000000)

# %%
category_type_installs = play_store.groupby(['Category','Type'])[['Installs']].sum().reset_index()
category_type_installs['log_Installs'] = np.log10(category_type_installs['Installs'])

# %%
plt.figure(figsize=(14,7))
plt.xticks(rotation=65,fontsize=9)
plt.xlabel('Category')
plt.ylabel('Installs')
plt.title('Number of Installed Apps type wise according to Category')
sns.barplot(x = 'Category',y = 'log_Installs',hue='Type',data=category_type_installs)
# Out:
# <Axes: title={'center': 'Number of Installed Apps type wise according to Category'}, xlabel='Category', ylabel='log_Installs'>

# %%
play_store['log_Installs'] = np.log10(category_type_installs['Installs'])

# %%
plt.figure(figsize=(14,7))
plt.xlabel('Size')
plt.ylabel('Installs')
plt.title('Impact of Application Size in Installation')
sns.scatterplot(x = 'Size',y = 'Installs',hue='Type',data=play_store)
# Out:
# <Axes: title={'center': 'Impact of Application Size in Installation'}, xlabel='Size', ylabel='Installs'>

# %%
#Category wise free and paid app installs count
category_type_installs = play_store.groupby(['Category','Type'])[['Installs']].sum().unstack().reset_index()
category_type_installs = category_type_installs[~category_type_installs['Installs']['Paid'].isna()].set_index('Category')
category_type_installs
# Out:
#                          Installs
# Type                         Free        Paid
# Category
# ART_AND_DESIGN       1.242121e+08     16000.0
# AUTO_AND_VEHICLES    5.307980e+07     50000.0
# BOOKS_AND_REFERENCE  1.921269e+09     22650.0
# BUSINESS             1.001355e+09    412660.0
# COMMUNICATION        3.264588e+10   1360000.0
# DATING               2.642740e+08     21100.0
# EDUCATION            8.707500e+08    602000.0
# ENTERTAINMENT        2.868960e+09    200000.0
# FAMILY               1.022643e+10  31218830.0
# FINANCE              8.764268e+08    185600.0
# FOOD_AND_DRINK       2.737178e+08     60000.0
# GAME                 3.506476e+10  21099262.0
# HEALTH_AND_FITNESS   1.582483e+09    573000.0
# LIFESTYLE            5.363820e+08   1179110.0
# MAPS_AND_NAVIGATION  7.241465e+08    121100.0
# MEDICAL              5.218898e+07   1016600.0
# NEWS_AND_MAGAZINES   7.496205e+09      5500.0
# PARENTING            3.106601e+07     50100.0
# ...

# %%
#Plot between Paid and Free installed app counts
ind = category_type_installs.index
column0 = category_type_installs['Installs']['Paid']
column1 = category_type_installs['Installs']['Free']
title0 = 'Paid app install Counts(in millions)'
title1 = 'Free app install Counts(in 100 millions)'

fig, axes = plt.subplots(figsize=(15,10), ncols=2, sharey=True)
fig.tight_layout()

axes[0].barh(ind, column0, align='center', color='orange', zorder=12)
axes[0].set_title(title0, fontsize=18, pad=15, color='orange')
axes[1].barh(ind, column1, align='center', color='g', zorder=12)
axes[1].set_title(title1, fontsize=18, pad=15, color='g')
    
plt.subplots_adjust(wspace=0.01, top=0.85, bottom=0.1, left=0.18, right=0.95)

# %% [markdown]
# 1. Family category has the most paid app installs.
# 2. Games category has the most free app installs.
#
#
# According to the stats, most paid apps are in family and games category. Apart from these no other category is doing good in making money. This also indicates that if the service provided is good and secured with quality, it will certainly create a positive impact on buisness and no otherwise.

# %%
play_store.corr()
# Out:
# <ipython-input-81-8ae6ab4943a0>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   play_store.corr()
#                 Rating      Size  Installs  log_Installs
# Rating        1.000000  0.045700  0.051337     -0.087590
# Size          0.045700  1.000000 -0.010417      0.081485
# Installs      0.051337 -0.010417  1.000000     -0.079352
# log_Installs -0.087590  0.081485 -0.079352      1.000000

# %%
plt.figure(figsize=(14,7))
sns.heatmap(play_store.corr(),cbar = True, cmap = 'coolwarm')
# Out:
# <ipython-input-82-35d5b6ea6963>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(play_store.corr(),cbar = True, cmap = 'coolwarm')
# <Axes: >

# %% [markdown]
# 1.  There is a majority of positive correlation between the Installs and Reviews columns. Greater the number of installs, higher is the user base, and major are the total number of reviews posted by the users.
#
# 2.  The Price is slightly negatively correlated with the Rating, Reviews, and Installs , concluding as the prices of the app increases, the average rating, total number of reviews and Installs decrease gradually.
#
# 3.  The Rating is marginally positively correlated with the Installs and Reviews` column. This points to the possibility that as the the average user rating grows, the app installs and number of reviews also increases.
#
# Based on the above observations we can conclude that it helps in creating the positive impact. The reason backing our conclusion is the growth of positive rating is directly proportional to the number of installs.

# %%
play_store['Installs'].max()
# Out:
# 1000000000

# %%
paid_apps = play_store[(play_store.Type=='Paid') & (play_store.Installs >=5000000)]
paid_apps = paid_apps.groupby('App')['Rating'].max().sort_values(ascending = False)

# %%
plt.figure(figsize=(14,7))
plt.xlabel('Rating')
sns.set_theme(style='whitegrid')
plt.title('Top 5 Paid Rated Apps')
sns.lineplot(x = paid_apps.values,y = paid_apps.index,color='Blue')
# Out:
# <Axes: title={'center': 'Top 5 Paid Rated Apps'}, xlabel='Rating', ylabel='App'>

# %%
plt.figure(figsize=(14,7))
data = play_store.groupby('Category')['Installs'].max().sort_values(ascending = True)
data = data.head(10)
labels = data.keys()
plt.pie(data,labels=labels,autopct='%.0f%%')
plt.title('Top 10 Installations Category wise',fontsize=14)
# Out:
# Text(0.5, 1.0, 'Top 10 Installations Category wise')

# %%
sentiment_subjectivity = user_reviews['Sentiment_Subjectivity']
sns.distplot(sentiment_subjectivity, hist=True , color ='r')
plt.xlabel("Subjectivity")
plt.title('Distribution of Subjectivity')
# Out:
# <ipython-input-87-4780fc60588d>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(sentiment_subjectivity, hist=True , color ='r')
# Text(0.5, 1.0, 'Distribution of Subjectivity')

# %% [markdown]
# We observed that maximum number of users post reviews to the apps which suits their experience.As we know sentiment subjectivity refers to the degree to which a piece of writing expresses personal opinions, feelings, or biases. And everyone has their own point of view. So, Sentiment subjectivity is inversely proportional to the growth of business.

# %%
plt.figure(figsize=(14,7))
plt.xlabel('Sentiment_Subjectivity')
plt.ylabel('Sentiment_Polarity')
plt.title('Relationship between Sentiment Polarity and Sentiment Subjectivity')
sns.scatterplot(x ='Sentiment_Subjectivity',y = 'Sentiment_Polarity',hue='Sentiment',data=user_reviews)
# Out:
# <Axes: title={'center': 'Relationship between Sentiment Polarity and Sentiment Subjectivity'}, xlabel='Sentiment_Subjectivity', ylabel='Sentiment_Polarity'>

# %% [markdown]
# The scatter plot which concludes that sentiment subjectivity is not likely proportional to sentiment polarity always.
# Proportional variance is too high or too low.Depending on the above plot yes and no as well. Reason is when polarity is positive and subjectivity is high it is a good product for individual. And the product is a complete garbage when subjectivity is low and polarity is negative.

# %%
user_reviews['Sentiment'].value_counts()
# Out:
# Positive    17593
# Negative     6240
# Neutral      4161
# Name: Sentiment, dtype: int64

# %%
#Percentage of Review sentiments
user_reviews['Sentiment'].value_counts().plot(kind='pie', explode= (0.1,0.1,0.1), shadow=True, autopct='%1.2f%%', pctdistance=1.1, labeldistance=1.5)
# Out:
# <Axes: ylabel='Sentiment'>

# %% [markdown]
# #***Suggession for business objective***
# In this project we analysed play store based on the data provided. The analysis done on given parameters would help client to enhance the properties of apps while launching , Most importantly provide a common ground to work on apps of different categories which need common updation. Initially I have focused more on cleaning and preparing the data for easy analysis that would help us get clear insights of playstore apps. After the analysis and plotting and working with data we would summarize our analysis to provide better and best results out of our work:
#
# Focusing on more updated and useful free apps because they are the most commonly used
# 1. Regular updatation of existing apps, to attract more new users.
# 2. There are some unexplored categories like event, beauty , art etc.
# 3. Developing apps in these categories would be helpful for users who have intrest in these areas.
# 4. Providing good content in apps that would be a factor in increasing the app market.
# 4. Users are more likely to have varying sentiments while using the app in each phase. So keeping the features that would be in favour of the majority of users is a factor that should have the focus.

# %% [markdown]
# #***Conclusion***
# 1. People are more interested to install the gaming apps,the top rating is given to the gaming apps.
# 2. App purchases are correlated to app rating. So we can say that if the app provides customer support and have subcription plans it will helps to engage customers.
# 3.  Most competitive category in paid and free: Family and Games.
# 4. Category with the highest average app installs: Game
# 5.  Percentage of apps that are top rated is ~80%.
# 6.  There are 20 free apps that have been installed over a billion time.
# 7.  Category in which the paid apps have the highest average installation fee: Finance
# 8. The apps whose size varies with device has the highest number average app installs.
# 9. Overall sentiment count of merged dataset in which Positive sentiment count is 64%, Negative 22% and Neutral 13%.
# 10.  Sentiment Polarity is not highly correlated with Sentiment Subjectivity.
# People are mostly downloaded the free apps the installation of the free apps is high and the availability of the free apps also is very high.
